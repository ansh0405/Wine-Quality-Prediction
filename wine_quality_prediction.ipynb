# %% [markdown]
# # Loading Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Collection

# %%
# Loading Dataset
wine_dataset = pd.read_csv('winequality.csv')

# %%
wine_dataset.shape
# Out:
# (102336, 12)

# %%
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Checking for missing values
wine_dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Data Analysis and Visualization

# %%
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity    citric acid  residual sugar  \
# count  102336.000000     102336.000000  102336.000000   102336.000000
# mean        8.319637          0.527821       0.270976        2.538806
# std         1.740560          0.179005       0.194741        1.409494
# min         4.600000          0.120000       0.000000        0.900000
# 25%         7.100000          0.390000       0.090000        1.900000
# 50%         7.900000          0.520000       0.260000        2.200000
# 75%         9.200000          0.640000       0.420000        2.600000
# max        15.900000          1.580000       1.000000       15.500000
#
#            chlorides  free sulfur dioxide  total sulfur dioxide  \
# count  102336.000000        102336.000000         102336.000000
# mean        0.087467            15.874922             46.467792
# std         0.047051            10.456937             32.885197
# min         0.012000             1.000000              6.000000
# ...

# %%
sns.catplot(x='quality', data = wine_dataset, kind = 'count')

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'fixed acidity', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'volatile acidity', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'citric acid', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'residual sugar', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'chlorides', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'total sulfur dioxide', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'sulphates', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y = 'alcohol', data = wine_dataset)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# Box plot for citric acid

# %%
# Extract the citric acid column
citric_acid = wine_dataset['citric acid']
# Create a box plot
plt.boxplot(citric_acid)
# Add labels and title
plt.xlabel('Citric Acid')
plt.ylabel('Value')
plt.title('Box plot of Citric Acid')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for volatile acidity

# %%
# Extract the volatile acidity column
volatile_acidity = wine_dataset['volatile acidity']
# Create a box plot
plt.boxplot(volatile_acidity)
# Add labels and title
plt.xlabel('Volatile Acidity')
plt.ylabel('Value')
plt.title('Box plot of Volatile Acidity')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for fixed acidity

# %%
# Extract the Fixed acidity column
fixed_acidity = wine_dataset['fixed acidity']
# Create a box plot
plt.boxplot(fixed_acidity)
# Add labels and title
plt.xlabel('Fixed Acidity')
plt.ylabel('Value')
plt.title('Box plot of Fixed Acidity')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for residual sugar

# %%
# Extract the residual sugar column
residual_sugar = wine_dataset['residual sugar']
# Create a box plot
plt.boxplot(residual_sugar)
# Add labels and title
plt.xlabel('Residual sugar')
plt.ylabel('Value')
plt.title('Box plot of Residual sugar')
# Show the plot
plt.show()

# %%
wine_dataset[wine_dataset['residual sugar'] >= 12].shape[0]
# Out:
# 512

# %%
wine_dataset[wine_dataset['residual sugar'] <= 12].shape[0]
# Out:
# 101824

# %%
wine_dataset.drop(wine_dataset[wine_dataset['residual sugar'] >= 12].index,inplace=True)

# %% [markdown]
# After removing outliers

# %%
# Extract the residual sugar column
residual_sugar = wine_dataset['residual sugar']
# Create a box plot
plt.boxplot(residual_sugar)
# Add labels and title
plt.xlabel('Residual sugar')
plt.ylabel('Value')
plt.title('Box plot of Residual sugar')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for chlorides

# %%
# Extract the Chlorides column
chlorides = wine_dataset['chlorides']
# Create a box plot
plt.boxplot(chlorides)
# Add labels and title
plt.xlabel('Chlorides')
plt.ylabel('Value')
plt.title('Box plot of Chlorides')
# Show the plot
plt.show()

# %%
wine_dataset[wine_dataset['chlorides'] <= 0.3].shape[0]
# Out:
# 100416

# %%
wine_dataset[wine_dataset['chlorides'] >= 0.3].shape[0]
# Out:
# 1408

# %%
wine_dataset.drop(wine_dataset[wine_dataset['chlorides'] >= 0.3].index,inplace=True)

# %% [markdown]
# After removing outliers

# %%
# Extract the Chlorides column
chlorides = wine_dataset['chlorides']
# Create a box plot
plt.boxplot(chlorides)
# Add labels and title
plt.xlabel('Chlorides')
plt.ylabel('Value')
plt.title('Box plot of Chlorides')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for sulfur dioxide

# %%
# Extract the free sulfur dioxide column
free_sulfur_dioxide	 = wine_dataset['free sulfur dioxide']
# Create a box plot
plt.boxplot(free_sulfur_dioxide)
# Add labels and title
plt.xlabel('Free sulfur dioxide')
plt.ylabel('Value')
plt.title('Box plot of Free sulfur dioxide')
# Show the plot
plt.show()

# %%
wine_dataset[wine_dataset['free sulfur dioxide'] >= 60].shape[0]
# Out:
# 192

# %%
wine_dataset[wine_dataset['free sulfur dioxide'] <= 60].shape[0]
# Out:
# 100224

# %%
wine_dataset.drop(wine_dataset[wine_dataset['free sulfur dioxide'] >= 60].index,inplace=True)

# %% [markdown]
# After removing outliers

# %%
# Extract the free sulfur dioxide column
free_sulfur_dioxide	 = wine_dataset['free sulfur dioxide']
# Create a box plot
plt.boxplot(free_sulfur_dioxide	)
# Add labels and title
plt.xlabel('Free sulfur dioxide')
plt.ylabel('Value')
plt.title('Box plot of Free sulfur dioxide')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for total sulfur dioxide

# %%
# Extract the free total sulfur dioxide column
total_sulfur_dioxide = wine_dataset['total sulfur dioxide']
# Create a box plot
plt.boxplot(total_sulfur_dioxide)
# Add labels and title
plt.xlabel('total sulfur dioxide')
plt.ylabel('Value')
plt.title('Box plot of total sulfur dioxide')
# Show the plot
plt.show()

# %%
wine_dataset[wine_dataset['total sulfur dioxide'] >= 200].shape[0]
# Out:
# 128

# %%
wine_dataset[wine_dataset['total sulfur dioxide'] <= 200].shape[0]
# Out:
# 100096

# %%
wine_dataset.drop(wine_dataset[wine_dataset['total sulfur dioxide'] >= 200].index,inplace=True)

# %% [markdown]
# after removing the ouliers

# %%
# Extract the free total sulfur dioxide column
total_sulfur_dioxide = wine_dataset['total sulfur dioxide']
# Create a box plot
plt.boxplot(total_sulfur_dioxide)
# Add labels and title
plt.xlabel('total sulfur dioxide')
plt.ylabel('Value')
plt.title('Box plot of total sulfur dioxide')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for density

# %%
# Extract the density column
density = wine_dataset['density']
# Create a box plot
plt.boxplot(density)
# Add labels and title
plt.xlabel('density')
plt.ylabel('Value')
plt.title('Box plot of density')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for pH

# %%
# Extract the pH column
pH = wine_dataset['pH']
# Create a box plot
plt.boxplot(pH)
# Add labels and title
plt.xlabel('pH')
plt.ylabel('Value')
plt.title('Box plot of pH')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for sulphates

# %%
# Extract the sulphates column
sulphates = wine_dataset['sulphates']
# Create a box plot
plt.boxplot(sulphates)
# Add labels and title
plt.xlabel('sulphates')
plt.ylabel('Value')
plt.title('Box plot of sulphates')
# Show the plot
plt.show()

# %%
wine_dataset[wine_dataset['sulphates'] >= 1.50].shape[0]
# Out:
# 320

# %%
wine_dataset[wine_dataset['sulphates'] <= 1.50].shape[0]
# Out:
# 99776

# %%
wine_dataset.drop(wine_dataset[wine_dataset['sulphates'] >= 1.50].index,inplace=True)

# %% [markdown]
# After removing the outliers

# %%
# Extract the sulphates column
sulphates = wine_dataset['sulphates']
# Create a box plot
plt.boxplot(sulphates)
# Add labels and title
plt.xlabel('sulphates')
plt.ylabel('Value')
plt.title('Box plot of sulphates')
# Show the plot
plt.show()

# %% [markdown]
# Box plot for alcohol

# %%
# Extract the alcohol column
alcohol = wine_dataset['alcohol']
# Create a box plot
plt.boxplot(alcohol)
# Add labels and title
plt.xlabel('alcohol')
plt.ylabel('Value')
plt.title('Box plot of alcohol')
# Show the plot
plt.show()

# %% [markdown]
# # Correlation
#
# 1.Positive correlation
# 2.Negative correlation

# %%
correlation = wine_dataset.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt = '.1f', annot = True, annot_kws={'size':8}, cmap = 'Blues')
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing

# %%
X = wine_dataset.drop('quality',axis=1)

# %%
print(X)
# Out:
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0                 7.4             0.700         0.00             1.9
# 1                 7.8             0.880         0.00             2.6
# 2                 7.8             0.760         0.04             2.3
# 3                11.2             0.280         0.56             1.9
# 4                 7.4             0.700         0.00             1.9
# ...               ...               ...          ...             ...
# 102331            6.2             0.600         0.08             2.0
# 102332            5.9             0.550         0.10             2.2
# 102333            6.3             0.510         0.13             2.3
# 102334            5.9             0.645         0.12             2.0
# 102335            6.0             0.310         0.47             3.6
#
#         chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Label Binarizaton

# %%
Y = wine_dataset['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
print(Y)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 102331    0
# 102332    0
# 102333    0
# 102334    0
# 102335    0
# Name: quality, Length: 99776, dtype: int64

# %% [markdown]
# # Train & Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (99776,) (79820,) (19956,)

# %% [markdown]
# # Model Training:

# %% [markdown]
# Random Forest Classifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Accuracy Score

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  1.0

# %% [markdown]
# r2 Score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y_test, X_test_prediction)
print("R2 Score: ", r2)
# Out:
# R2 Score:  1.0

# %%
# get feature importances
feature_importances = model.feature_importances_

# sort features by importance in descending order
indices = np.argsort(feature_importances)[::-1]

# print feature ranking
print("Feature ranking:")
for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], feature_importances[indices[f]]))

# create horizontal bar chart
wine_feature_names = X.columns
plt.barh(range(X_train.shape[1]), feature_importances[indices], align='center')
plt.yticks(range(X_train.shape[1]), wine_feature_names[indices])
plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.ylim([-1, X_train.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 10 (0.162582)
# 2. feature 9 (0.124603)
# 3. feature 1 (0.110118)
# 4. feature 7 (0.093049)
# 5. feature 2 (0.085281)
# 6. feature 6 (0.080824)
# 7. feature 4 (0.076661)
# 8. feature 0 (0.072088)
# 9. feature 3 (0.068038)
# 10. feature 5 (0.064293)
# 11. feature 8 (0.062464)

# %% [markdown]
# Building a Predictive System

# %%
wine_dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
input_data = (7.5,0.5,0.36,6.1,0.071,17.0,102.0,0.9978,3.35,0.8,10.5)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [0]
# Bad Quality Wine
# c:\Users\parhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors = 100)
# Fit the classifier to the data
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %% [markdown]
# Accuracy Score

# %%
X_test_prediction_knn = knn.predict(X_test)
accuracy_knn = accuracy_score(X_test_prediction_knn, Y_test)
print("KNN: " + str(accuracy_knn * 100))
# Out:
# KNN: 95.8709160152335

# %% [markdown]
# r2 Score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y_test, X_test_prediction)
print("R2 Score: ", r2)
# Out:
# R2 Score:  1.0

# %%
importance = model.feature_importances_
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))

# create horizontal bar chart
wine_feature_names = X.columns
plt.barh(range(X_train.shape[1]), feature_importances[indices], align='center')
plt.yticks(range(X_train.shape[1]), wine_feature_names[indices])
plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.ylim([-1, X_train.shape[1]])
plt.show()
# Out:
# Feature: 0, Score: 0.07209
# Feature: 1, Score: 0.11012
# Feature: 2, Score: 0.08528
# Feature: 3, Score: 0.06804
# Feature: 4, Score: 0.07666
# Feature: 5, Score: 0.06429
# Feature: 6, Score: 0.08082
# Feature: 7, Score: 0.09305
# Feature: 8, Score: 0.06246
# Feature: 9, Score: 0.12460
# Feature: 10, Score: 0.16258

# %% [markdown]
# Building a Predictive System

# %%
input_data = (8.5,0.28,0.56,1.8,0.092,35,103,0.9969,3.3,0.75,10.5)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [1]
# Good Quality Wine
# c:\Users\parhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Naive Bayes Classification

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Accuracy Score

# %%
X_test_prediction_nb = nb.predict(X_test)
accuracy_nb = accuracy_score(X_test_prediction_nb, Y_test)
print("Naive Bayes: " + str(accuracy_nb * 100))
# Out:
# Naive Bayes: 85.26758869512928

# %% [markdown]
# r2 Score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y_test, X_test_prediction)
print("R2 Score: ", r2)
# Out:
# R2 Score:  1.0

# %% [markdown]
# Building a Predictive System

# %%
input_data = (7.9,0.32,0.51,1.8,0.341,17,56,0.9969,3.04,1.08,9.2)

# changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data as we are predicting the label for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==1):
  print('Good Quality Wine')
else:
  print('Bad Quality Wine')
# Out:
# [0]
# Bad Quality Wine
# c:\Users\parhi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
# import joblib

# # save the model as a pkl file
# joblib.dump(model, 'wine_quality_model.pkl')
